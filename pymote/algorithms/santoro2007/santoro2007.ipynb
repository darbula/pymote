# %%
# %matplotlib inline

# %%
from YoYo import YoYo


# Create a custom network to run YoYo on
net = Network()

# Define node range and positions (IDs are dependent on position in list)
node_range = 101
node_positions = [(100, 500), (300, 400), (300, 100), (200, 500), (400, 200), 
                  (100, 400), (400, 100), (200, 400), (400, 300), (400, 400), 
                  (300, 200)]

# Add nodes
for node_pos in node_positions:
    net.add_node(pos=node_pos, commRange=node_range)

# Show network
net.show()

# Set algorithm and create simulation
net.algorithms = (YoYo, )
sim = Simulation(net, logLevel='WARNING')

# Run simulation
sim.run()

# %%
# Define number of nodes in random network
NUM_NODES = 20

# Create a random network to run YoYo on
net_gen = NetworkGenerator(NUM_NODES)
net = net_gen.generate_random_network()

# Show network
net.show()

# Set algorithm and create simulation
net.algorithms = (YoYo, )
sim = Simulation(net, logLevel='WARNING')

# Run simulation
sim.run()
